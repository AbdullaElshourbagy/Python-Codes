# %% [markdown]
# <h3> Scrap the USD To EGP Exchange rate from this website</h3> <br> <a href="https://www.exchangerates.org.uk/Dollars-to-Egyptian-Pounds-currency-conversion-page.html">Exchange Site</a>
# <br> and then use it to make a software that takes amount of USD Dollars from the user and calculate how much will it cost in EGP.

# %%
import requests
from bs4 import BeautifulSoup

# %%
dollars = float(input('Enter dollars: '))
# Out:
# Enter dollars: 20.5

# %%
url='https://www.exchangerates.org.uk/Dollars-to-Egyptian-Pounds-currency-conversion-page.html'
response = requests.request('GET',url)
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title>Dollar to Egyptian Pound Exchange Rate Today, Live 1 USD to EGP = 15.6878 (Convert Dollars to Egyptian Pounds)</title>
# <meta content="Compare the best Dollar Egyptian Pound exchange rate deals &amp; Dollars to Egyptian Pounds exchange today! Live Dollar to Egyptian Pound exchange rate comparison tables, charts and USD EGP history" name="description"/>
# <meta content="Dollars to Egyptian Pounds , USD EGP, 1 USD to EGP" name="keywords"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <script>
#   (function (i, s, o, g, r, a, m) {
#     i['GoogleAnalyticsObject'] = r;
#     i[r] = i[r] || function () {
#           (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date();
#     a = s.createElement(o),
#         m = s.getElementsByTagName(o)[0];
# ...

# %%
exchange_rate = float(soup.find('span', attrs={'id': 'shd2b;'}).get_text())
exchange_rate
# Out:
# 15.6878

# %%
result = exchange_rate * dollars

print('Exchange Result >>>>')
print(str(dollars) + ' USD = ' + str(result) + ' EGP')
# Out:
# Exchange Result >>>>
# 20.5 USD = 321.5999 EGP

# %% [markdown]
# ## End Work!
# ### By Abdulla Elshourbagy.
